# %%
import numpy as np
import pandas as pd
from make_data import make_data

X = np.array([[1,2,3],[3,4,5]])
X.reshape((-1,6))
# Out:
# array([[1, 2, 3, 3, 4, 5]])

# %%
X, y =  make_data(n_features=2, n_pts=300, noise=0.1)
X, y
# Out:
# (array([[-0.65347622, -0.9121879 ],
#         [ 0.19059348, -0.57607224],
#         [-0.07751006,  0.54006522],
#         [ 0.95438136,  0.65897859],
#         [ 0.60251112,  0.14160905],
#         [-0.45296051,  0.32896805],
#         [-0.95646171, -0.75616447],
#         [ 0.91721211,  0.69161244],
#         [ 0.21924292,  0.1559606 ],
#         [ 0.89802754, -0.69775181],
#         [-0.72246168,  0.01467411],
#         [-0.47983513,  0.34059427],
#         [-0.23289636, -0.18435702],
#         [-0.5145962 ,  0.77431852],
#         [-0.9365595 , -0.44324567],
#         [-0.25483341,  0.57506392],
#         [-0.75250198, -0.62865062],
#         [ 0.79278975, -0.03001763],
#         [-0.25766882, -0.53260038],
#         [ 0.37309742,  0.51955143],
#         [-0.54691192,  0.6150471 ],
#         [ 0.63084926, -0.76499186],
#         [-0.06072992, -0.72077829],
#         [ 0.1930462 ,  0.35983105],
#         [ 0.31626655,  0.93557798],
#         [ 0.55134696, -0.22961731],
# ...

# %%
b, c = np.array([1,2]).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-093bd32749ea> in <module>
# ----> 1 b, c = np.array([1,2]).shape
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
c
# Out:
# 2
